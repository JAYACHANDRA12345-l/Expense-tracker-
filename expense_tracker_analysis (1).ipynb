# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv("expense_tracker_dataset.csv")
df.head()
# Out:
#          Date Description       Category  Amount
# 0  01-01-2025       Lunch          Food      200
# 1  02-01-2025  Bus Ticket      Transport      50
# 2  03-01-2025       Movie  Entertainment     300
# 3  04-01-2025     T-shirt       Shopping     700
# 4  05-01-2025      Coffee          Food      120

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         5 non-null      str
#  1   Description  5 non-null      str
#  2   Category     5 non-null      str
#  3   Amount       5 non-null      int64
# dtypes: int64(1), str(3)
# memory usage: 292.0 bytes

# %%
total_expense = df["Amount"].sum()
print("Total Expense:", total_expense)
# Out:
# Total Expense: 1370

# %%
df.groupby("Category")["Amount"].sum()
# Out:
# Category
# Entertainment    300
# Food             320
# Shopping         700
# Transport         50
# Name: Amount, dtype: int64

# %%
sns.barplot(x="Category", y="Amount", data=df)
plt.title("Expense by Category")
plt.show()

# %%
df.groupby("Category")["Amount"].sum().plot(
    kind="pie",
    autopct="%1.1f%%"
)

plt.title("Expense Distribution")
plt.ylabel("")
plt.show()
